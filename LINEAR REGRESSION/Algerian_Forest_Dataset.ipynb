# %% [markdown]
# # LINEAR REGRESSION:

# %% [markdown]
# ### Algerian Forest Fires Dataset Information:

# %% [markdown]
# The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012. The dataset includes 11 attribues and 1 output attribue (class) The 244 instances have been classified into fire(138 classes) and not fire (106 classes) classes.
#
# Attribute Information:
#
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8 FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely Fire and not Fire

# %% [markdown]
# #### Life cycle Project:

# %% [raw]
# 1.Data Collection
# 2.Exploratory data analysis
# 3.Data Cleaning
# 4.Data Pre-Processing
# 5.Model Training
# 6.Model Selection

# %% [markdown]
# #### 1.Data Collection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings 
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\arnab\Documents\DATA SCIENCE\DATASETS\Algerian_forest_fires_dataset_UPDATE.csv", header = 1)
df.shape
# Out:
# (246, 14)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.width', 1000,
                       'display.precision', 3):
    display(df)
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC      DC   ISI   BUI      FWI      Classes
# 0                               01     06  2012           29   57   18      0  65.7   3.4     7.6   1.3   3.4      0.5    not fire
# 1                               02     06  2012           29   61   13    1.3  64.4   4.1     7.6     1   3.9      0.4    not fire
# 2                               03     06  2012           26   82   22   13.1  47.1   2.5     7.1   0.3   2.7      0.1    not fire
# 3                               04     06  2012           25   89   13    2.5  28.6   1.3     6.9     0   1.7        0    not fire
# 4                               05     06  2012           27   77   16      0  64.8     3    14.2   1.2   3.9      0.5    not fire
# 5                               06     06  2012           31   67   14      0  82.6   5.8    22.2   3.1     7      2.5        fire
# ...

# %%
df.loc[:122,"Region"]=0 
df.loc[122:,"Region"]=1
df["Region"] = df["Region"].astype(int)

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
# RH             1
# Ws             1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 28.0+ KB

# %%
# Based on analyzing the dataframe we have to remove row 122, 123 and 167.
# 122: Because of NA values 
# 123: Because of odd value types

df = df.drop([122,123]).reset_index(drop=True)
df.at[165,'DC'] = 14.6
df.at[165,'ISI'] = 9
df.at[165,'BUI'] = 12.5
df.at[165,'FWI'] = 10.4
df.at[165,'Classes'] = 'fire'
df.shape
# Out:
# (244, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4   RH           244 non-null    object
#  5   Ws           244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       244 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 27.8+ KB

# %% [raw]
# Abbreviation and meaning of Parameters
# •RH = Relative Humidity: Relative humidity (RH) is the amount of water vapor in the air compared to the maximum amount possible at that temperature.
#
# •Ws = Wind Speed
#
# •FFMC = Fine Fuel Moisture Code: This code is an indicator of the relative ease of ignition and the flammability of fine fuels.
# •DMC = Duff Moisture Code: This code gives an indication of fuel consumption in moderate duff layers and medium-size woody material.
#
# •DC = Drought Code: The Drought Code (DC) is a numeric rating of the average moisture content of deep, compact organic layers.
#
# •ISI = Initial Spread Index: The Initial Spread Index (ISI) is a numeric rating of the expected rate of fire spread. It is based on wind speed and Fine Fuel Moisture Code (FFMC).
#
# •BUI = Build Up Index: The Buildup Index (BUI) is a numeric rating of the total amount of fuel available for combustion.
#
# •FWI = Fire Weather Index: FWI) is a system used to estimate the potential for wildfires. It is based on weather conditions, such as temperature, humidity, wind speed, and fuel moisture.
#
# •classes = Two Classes(Fire, Not Fire)

# %%
##Changing data type of first 6 columns to Int
df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']] = df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)
df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']] = df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)

# %%
df['date'] = pd.to_datetime(df[['year', 'month', 'day']].astype(str).apply('-'.join, 1))
df.drop(['day','month','year'],axis=1, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  244 non-null    int32
#  1   RH           244 non-null    int32
#  2   Ws           244 non-null    int32
#  3   Rain         244 non-null    float64
#  4   FFMC         244 non-null    float64
#  5   DMC          244 non-null    float64
#  6   DC           244 non-null    float64
#  7   ISI          244 non-null    float64
#  8   BUI          244 non-null    float64
#  9   FWI          244 non-null    float64
#  10  Classes      244 non-null    object
#  11  Region       244 non-null    int32
#  12  date         244 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int32(4), object(1)
# memory usage: 21.1+ KB

# %%
df.describe().T
# Out:
#              count       mean        std   min     25%    50%     75%    max
# Temperature  244.0  32.172131   3.633843  22.0  30.000  32.00  35.000   42.0
# RH           244.0  61.938525  14.884200  21.0  52.000  63.00  73.250   90.0
# Ws           244.0  15.504098   2.810178   6.0  14.000  15.00  17.000   29.0
# Rain         244.0   0.760656   1.999406   0.0   0.000   0.00   0.500   16.8
# FFMC         244.0  77.887705  14.337571  28.6  72.075  83.50  88.300   96.0
# DMC          244.0  14.673361  12.368039   0.7   5.800  11.30  20.750   65.9
# DC           244.0  49.288115  47.619662   6.9  13.275  33.10  68.150  220.4
# ISI          244.0   4.759836   4.154628   0.0   1.400   3.50   7.300   19.0
# BUI          244.0  16.673361  14.201648   1.1   6.000  12.45  22.525   68.0
# FWI          244.0   7.049180   7.428366   0.0   0.700   4.45  11.375   31.1
# Region       244.0   0.500000   0.501028   0.0   0.000   0.50   1.000    1.0

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Numerical and Categorical Variable
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

#print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('We have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 12 numerical features : ['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Region', 'date']
# We have 1 categorical features : ['Classes']

# %% [markdown]
# ### Univariate Analysis

# %%
#Univariate Analysis of Numerical Feature

plt.figure(figsize=(15,15))
for i in range(0,len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True,color='b')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
#Proportion of data count on Categorical Columns
for col in categorical_features:
    print((df[col].value_counts()/df.shape[0])*100)
    print('--------------------------------------------')
# Out:
# fire             53.688525
# not fire         41.393443
# fire              2.049180
# fire              0.819672
# not fire          0.819672
# not fire          0.409836
# not fire          0.409836
# not fire          0.409836
# Name: Classes, dtype: float64
# --------------------------------------------

# %%
#Since categorical column has more than two categories of data due to spelling, will transform.
df['Classes'] = df['Classes'].str.strip()

# %%
#Proportion of data count on Categorical Columns
for col in categorical_features:
    print((df[col].value_counts()/df.shape[0])*100)
    print('--------------------------------------------')
    
## Percentage for Pie Chart
percentage=df['Classes'].value_counts(normalize=True)*100
# plotting piechart
classlabels=["Fire","Not Fire"]
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title("Pie Chart of Classes")
plt.show()
# Out:
# fire        56.557377
# not fire    43.442623
# Name: Classes, dtype: float64
# --------------------------------------------

# %% [markdown]
# ### Bivariate Analysis

# %%
for feature in numeric_features:
    plt.figure(figsize=(15,15))
    sns.histplot(data=df,x=feature,hue='Classes')
    plt.show()

# %% [markdown]
# ### Observations

# %% [markdown]
# 1. Temperature does matter for cases of fire because we have seen after temp = 40,
#     there are not cases of "No Fire" but cases are even reported when temp > 25.
# 2. Incase of RH, spread of data is from 20 to 100, but when relative humidity is high cases of fire is not reported.
# 3. Incase of FFMC, cases of fire spiked after FFMC > 75. Almost all cases of fire reported after FFMC > 86.
# 4. Incase of DMC, cases of fire is spreaded across all values, but cases are more when DMC > 5
# 5. Incase of DC, observation is quiet similar to DMC.
# 6. Most cases of fire have occured in the  whole month of August(08).

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ### Directly correlated:
# #####                    1. DMC with BUI : 98%
# #####                    2. BUI with DC : 94%
# #####                    3. ISI with FWI : 92%
# #####                    4. DMC with DC : 88%
# #####                    5. DMC with FWI : 88%
# #####                    6. FFMC with ISI : 74%
# #####                    7. FWI have a certainly high correlation with FFMC, DMC, DC, ISI & BUI

# %% [markdown]
# ### Monthly Fire Analysis of Sidi- Bel Region & Brjaia Regions

# %%
dftemp=df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x=df['date'].dt.month,hue='Classes',data=df)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Sidi- Bel Region",weight='bold')

dftemp=df.loc[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x=df['date'].dt.month,hue='Classes',data=df)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Brjaia Regions Region",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Brjaia Regions Region')

# %% [markdown]
# ### Lets look at outliers

# %%
plt.figure(figsize = (17,8))
sns.boxplot(data = df)
# Out:
# <Axes: >

# %% [markdown]
# #### RH and Region contains no outliers.
# #### Wind Speed has outliers both below Q1 and above Q3.
# #### FFMC and Temperature are fetaures with outliers below Q1.
# #### DMC, DC, ISI, BUI, Rain and FWI with outliers above Q3.

# %%
## chaanging the classes 
df['Classes'] = df['Classes'].replace('not fire','0')
df['Classes'] = df['Classes'].replace('fire','1')

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI Classes  Region  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5       0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4       0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1       0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0       0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5       0       0
#
#         date
# 0 2012-06-01
# 1 2012-06-02
# 2 2012-06-03
# 3 2012-06-04
# 4 2012-06-05

# %%
## Independent And Dependent Features
X=df.iloc[:,1:-1]
y=df.iloc[:,0]

# %%
X
# Out:
#      RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI Classes  Region
# 0    57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5       0       0
# 1    61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4       0       0
# 2    82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1       0       0
# 3    89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0       0       0
# 4    77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5       0       0
# ..   ..  ..   ...   ...   ...   ...  ...   ...  ...     ...     ...
# 239  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5       1       1
# 240  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0       0       1
# 241  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2       0       1
# 242  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7       0       1
# 243  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5       0       1
#
# [244 rows x 11 columns]

# %%
y
# Out:
# 0      29
# 1      29
# 2      26
# 3      25
# 4      27
#        ..
# 239    30
# 240    28
# 241    27
# 242    24
# 243    24
# Name: Temperature, Length: 244, dtype: int32

# %% [markdown]
# ### Spliting the data into train and test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=24)

# %%
print("X_train: "+str(X_train.shape))
print("y_train: "+str(y_train.shape))
print("X_test: "+str(X_test.shape))
print("y_test: "+str(y_test.shape))
# Out:
# X_train: (163, 11)
# y_train: (163,)
# X_test: (81, 11)
# y_test: (81,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train,y_train)
print("Coefficient: "+str(regression.coef_))
print("----------------------------------------------")
print("Intercept: "+str(regression.intercept_))
reg_pred=regression.predict(X_test)
# Out:
# Coefficient: [-0.73763956 -0.25703846  0.00856449  1.96602786 -0.01823143  0.91299919
#   0.67100834 -0.34509289 -0.3711152  -0.50926166  0.41443391]
# ----------------------------------------------
# Intercept: 32.04294478527607

# %% [markdown]
# ### Linear Regression

# %%
plt.scatter(y_test,reg_pred)
plt.xlabel("Test Truth Data")
plt.ylabel("Test Predicted Data")
# Out:
# Text(0, 0.5, 'Test Predicted Data')

# %%
residuals=y_test-reg_pred
sns.displot(residuals,kind="kde")

# %%
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print("MSE: "+str(mean_squared_error(y_test,reg_pred)))
print("MAE: "+str(mean_absolute_error(y_test,reg_pred)))
print("RMSE: "+str(np.sqrt(mean_squared_error(y_test,reg_pred))))

from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print("R Square: "+str(score))
print("Adjusted R Square: "+str(1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)))
# Out:
# MSE: 7.598485769409661
# MAE: 2.152480520752898
# RMSE: 2.756535102154453
# R Square: 0.40468970752415967
# Adjusted R Square: 0.3097851681439532

# %% [markdown]
# ## Ridge

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge=Ridge()
ridge.fit(X_train,y_train)
y_pred=ridge.predict(X_test)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)

plt.scatter(y_test,y_pred)
plt.xlabel("Test Truth Data")
plt.ylabel("Test Predicted Data")

residuals=y_test-y_pred
sns.displot(residuals,kind="kde")
# Out:
# Mean absolute error 2.140942935491009
# R2 Score 0.4099794060860159

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso=Lasso()
lasso.fit(X_train,y_train)
y_pred=lasso.predict(X_test)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 2.2603928476283595
# R2 Score 0.344295898316774

# %% [markdown]
# ## Elasticnet

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elastic=ElasticNet()
elastic.fit(X_train,y_train)
y_pred=elastic.predict(X_test)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 2.161477734338505
# R2 Score 0.39959139074239536
